# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv('mobile_price_classification.csv')

# %%
data.head(20)
# Out:
#     battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  \
# 0             842          0          2.2         0          1   0
# 1            1021          1          0.5         1          0   1
# 2             563          1          0.5         1          2   1
# 3             615          1          2.5         0          0   0
# 4            1821          1          1.2         0         13   1
# 5            1859          0          0.5         1          3   0
# 6            1821          0          1.7         0          4   1
# 7            1954          0          0.5         1          0   0
# 8            1445          1          0.5         0          0   0
# 9             509          1          0.6         1          2   1
# 10            769          1          2.9         1          0   0
# 11           1520          1          2.2         0          5   1
# 12           1815          0          2.8         0          2   0
# 13            803          1          2.1         0          7   0
# 14           1866          0          0.5         0         13   1
# 15            775          0          1.0         0          3   0
# 16            838          0          0.5         0          1   1
# 17            595          0          0.9         1          7   1
# 18           1131          1          0.5         1         11   0
# 19            682          1          0.5         0          4   0
#
#     int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0            7    0.6        188        2  ...         20       756  2549
# 1           53    0.7        136        3  ...        905      1988  2631
# 2           41    0.9        145        5  ...       1263      1716  2603
# 3           10    0.8        131        6  ...       1216      1786  2769
# 4           44    0.6        141        2  ...       1208      1212  1411
# 5           22    0.7        164        1  ...       1004      1654  1067
# 6           10    0.8        139        8  ...        381      1018  3220
# 7           24    0.8        187        4  ...        512      1149   700
# 8           53    0.7        174        7  ...        386       836  1099
# 9            9    0.1         93        5  ...       1137      1224   513
# 10           9    0.1        182        5  ...        248       874  3946
# 11          33    0.5        177        8  ...        151      1005  3826
# 12          33    0.6        159        4  ...        607       748  1482
# 13          17    1.0        198        4  ...        344      1440  2680
# 14          52    0.7        185        1  ...        356       563   373
# 15          46    0.7        159        2  ...        862      1864   568
# 16          13    0.1        196        8  ...        984      1850  3554
# 17          23    0.1        121        3  ...        441       810  3752
# 18          49    0.6        101        5  ...        658       878  1835
# 19          19    1.0        121        4  ...        902      1064  2337
#
#     sc_h  sc_w  talk_time  three_g  touch_screen  wifi  price_range
# 0      9     7         19        0             0     1            1
# 1     17     3          7        1             1     0            2
# 2     11     2          9        1             1     0            2
# 3     16     8         11        1             0     0            2
# 4      8     2         15        1             1     0            1
# 5     17     1         10        1             0     0            1
# 6     13     8         18        1             0     1            3
# 7     16     3          5        1             1     1            0
# 8     17     1         20        1             0     0            0
# 9     19    10         12        1             0     0            0
# 10     5     2          7        0             0     0            3
# 11    14     9         13        1             1     1            3
# 12    18     0          2        1             0     0            1
# 13     7     1          4        1             0     1            2
# 14    14     9          3        1             0     1            0
# 15    17    15         11        1             1     1            0
# 16    10     9         19        1             0     1            3
# 17    10     2         18        1             1     0            3
# 18    19    13         16        1             1     0            1
# 19    11     1         18        0             1     1            1
#
# [20 rows x 21 columns]

# %%
data.isna().sum()
# Out:
# battery_power     0
# bluetooth         0
# clock_speed       0
# dual_sim          0
# front_cam         0
# 4G                0
# int_memory        0
# m_dep             0
# mobile_wt         0
# n_cores           0
# primary_camera    0
# px_height         0
# px_width          0
# ram               0
# sc_h              0
# sc_w              0
# talk_time         0
# three_g           0
# touch_screen      0
# wifi              0
# price_range       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['battery_power', 'bluetooth', 'clock_speed', 'dual_sim', 'front_cam',
#        '4G', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'primary_camera',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#sns.pairplot(data[['battery_power', 'bluetooth', 'clock_speed', 'dual_sim', 'front_cam',
       #'4G', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'primary_camera',
       #'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       #'touch_screen', 'wifi']])
#plt.show()

# %%
x=data[['battery_power', 'bluetooth', 'clock_speed', 'dual_sim', 'front_cam',
       '4G', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'primary_camera',
       'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]
y=data['price_range']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs =10)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3151 - loss: 193.1927
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4605 - loss: 15.6255
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5444 - loss: 8.3168
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5042 - loss: 7.2283
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5514 - loss: 5.3025
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5363 - loss: 4.5563
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5277 - loss: 3.9852
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5444 - loss: 3.4007
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5773 - loss: 2.8639
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5675 - loss: 2.5958

# %%
y_pred =np.argmax(model.predict(x_test),axis=1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.5925

# %%
y_pred
# Out:
# array([0, 1, 0, 3, 1, 3, 2, 0, 3, 1, 0, 1, 2, 2, 2, 1, 1, 3, 1, 0, 0, 2,
#        1, 2, 0, 3, 3, 2, 2, 1, 1, 1, 3, 0, 2, 2, 1, 1, 1, 0, 0, 2, 2, 0,
#        3, 2, 2, 1, 3, 1, 3, 2, 0, 0, 2, 1, 1, 2, 0, 0, 1, 3, 2, 2, 1, 1,
#        1, 2, 0, 1, 3, 1, 0, 1, 1, 0, 0, 3, 2, 1, 3, 2, 1, 1, 1, 3, 1, 3,
#        3, 0, 3, 2, 3, 1, 3, 1, 2, 3, 1, 1, 0, 1, 1, 0, 1, 2, 1, 0, 0, 1,
#        0, 0, 2, 2, 3, 1, 2, 2, 0, 2, 1, 3, 2, 1, 3, 2, 0, 3, 1, 1, 3, 0,
#        1, 1, 0, 2, 1, 1, 0, 1, 2, 0, 2, 3, 0, 0, 1, 2, 1, 2, 2, 1, 1, 0,
#        2, 3, 0, 1, 0, 1, 2, 3, 1, 1, 1, 0, 0, 1, 2, 1, 2, 1, 1, 0, 3, 1,
#        1, 3, 1, 1, 0, 0, 0, 0, 2, 1, 0, 2, 0, 0, 0, 0, 1, 3, 2, 1, 0, 2,
#        0, 1, 1, 3, 2, 1, 3, 1, 0, 3, 0, 0, 0, 1, 2, 1, 2, 1, 1, 2, 3, 1,
#        3, 2, 2, 0, 0, 3, 1, 2, 0, 0, 1, 0, 2, 3, 2, 1, 1, 1, 3, 1, 3, 3,
#        2, 3, 0, 2, 3, 2, 3, 3, 2, 2, 0, 2, 3, 1, 3, 3, 3, 2, 3, 0, 3, 2,
#        2, 1, 2, 0, 2, 3, 2, 2, 3, 1, 1, 2, 0, 3, 3, 1, 2, 1, 1, 1, 1, 3,
#        0, 0, 2, 1, 2, 1, 2, 3, 1, 0, 1, 0, 0, 3, 2, 1, 1, 1, 2, 0, 2, 3,
#        2, 3, 2, 2, 3, 0, 2, 1, 3, 3, 0, 0, 1, 2, 2, 3, 1, 1, 2, 1, 2, 2,
#        3, 0, 2, 1, 1, 1, 2, 0, 0, 3, 1, 1, 3, 0, 1, 1, 1, 1, 3, 2, 2, 1,
#        1, 2, 3, 0, 3, 0, 0, 2, 0, 1, 1, 2, 2, 2, 1, 0, 2, 2, 3, 3, 1, 3,
#        1, 3, 0, 2, 1, 3, 3, 0, 2, 3, 2, 3, 3, 3, 2, 0, 2, 3, 1, 0, 3, 3,
#        2, 1, 2, 2], dtype=int64)
